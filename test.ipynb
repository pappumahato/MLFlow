# %%
import pandas as pd
import numpy as np

# %%
# df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv',sep=';')
data = pd.read_csv('data\winequality-red.csv',sep=';')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
from sklearn.model_selection import train_test_split

train,test=train_test_split(data)

# %%
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1323            9.1              0.36         0.39             1.8      0.060
# 597            11.9              0.58         0.58             1.9      0.071
# 1544            8.4              0.37         0.43             2.3      0.063
# 943             9.8              0.50         0.34             2.3      0.094
# 550             6.8              0.51         0.01             2.1      0.074
# ...             ...               ...          ...             ...        ...
# 1452            6.6              0.58         0.02             2.0      0.062
# 448             8.6              0.53         0.22             2.0      0.100
# 563             7.6              0.29         0.49             2.7      0.092
# 615             9.6              0.60         0.50             2.3      0.079
# 783             6.5              0.46         0.14             2.4      0.114
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1323                 21.0                  55.0  0.99495  3.18       0.82
# 597                   5.0                  18.0  0.99800  3.09       0.63
# 1544                 12.0                  19.0  0.99550  3.17       0.81
# 943                  10.0                  45.0  0.99864  3.24       0.60
# 550                   9.0                  25.0  0.99580  3.33       0.56
# ...                   ...                   ...      ...   ...        ...
# 1452                 37.0                  53.0  0.99374  3.35       0.76
# 448                   7.0                  27.0  0.99670  3.20       0.56
# 563                  25.0                  60.0  0.99710  3.31       0.61
# 615                  28.0                  71.0  0.99970  3.50       0.57
# 783                   9.0                  37.0  0.99732  3.66       0.65
#
#       alcohol  quality
# 1323     11.0        7
# 597      10.0        6
# 1544     11.2        7
# 943       9.7        7
# 550       9.5        6
# ...       ...      ...
# 1452     11.6        7
# 448      10.2        6
# 563      10.1        6
# 615       9.7        5
# 783       9.8        5
#
# [1199 rows x 12 columns]

# %%
test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1190            9.1             0.400         0.57             4.6      0.080
# 1207            9.9             0.720         0.55             1.7      0.136
# 112             8.4             0.600         0.10             2.2      0.085
# 513            10.5             0.510         0.64             2.4      0.107
# 1218            8.2             0.400         0.31             1.9      0.082
# ...             ...               ...          ...             ...        ...
# 132             5.6             0.500         0.09             2.3      0.049
# 63              7.0             0.735         0.05             2.0      0.081
# 1106            8.2             0.230         0.42             1.9      0.069
# 602             7.7             0.835         0.00             2.6      0.081
# 1356            6.1             0.340         0.25             1.8      0.084
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1190                  6.0                  20.0  0.99652  3.28       0.57
# 1207                 24.0                  52.0  0.99752  3.35       0.94
# 112                  14.0                 111.0  0.99640  3.15       0.66
# 513                   6.0                  15.0  0.99730  3.09       0.66
# 1218                  8.0                  24.0  0.99600  3.24       0.69
# ...                   ...                   ...      ...   ...        ...
# 132                  17.0                  99.0  0.99370  3.63       0.63
# 63                   13.0                  54.0  0.99660  3.39       0.57
# 1106                  9.0                  17.0  0.99376  3.21       0.54
# 602                   6.0                  14.0  0.99750  3.30       0.52
# 1356                  4.0                  28.0  0.99464  3.36       0.44
#
#       alcohol  quality
# 1190     12.5        6
# 1207     10.0        5
# 112       9.8        5
# 513      11.8        7
# 1218     10.6        6
# ...       ...      ...
# 132      13.0        5
# 63        9.8        5
# 1106     12.3        6
# 602       9.3        5
# 1356     10.1        5
#
# [400 rows x 12 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import ElasticNet

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split

# %%
X_train=train.drop(['quality'],axis=1)
X_test=test.drop(['quality'],axis=1)

y_train=train[['quality']]
y_test=test[['quality']]

# %%
rf=RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# c:\Users\mpapp\Desktop\ineuron\project\mlflow\venv\lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
pred_prob=rf.predict_proba(X_test)

# %%
roc_auc_score=roc_auc_score(y_test,pred_prob,multi_class='ovr')

# %%
roc_auc_score
# Out:
# 0.8493837596921502
